# %% [markdown]
# <a href="https://colab.research.google.com/github/filiperobotic/cursoDL/blob/master/codes/aula1/ajuste_linha_resposta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  
import matplotlib.pyplot as plt  

#função para plotar o gráfico
def graph(formula, x_range, ls='-'):  
    x = np.array(x_range)  
    y = eval(formula)
    plt.scatter(point[0], point[1], s=50, c='b')
    plt.plot(x, y, ls=ls)

# %%
#função de checagem se o ponto está dentro da região ou não
def check(weight1, weight2, bias):
  if (weight1*point[0]+weight2*point[1]+bias >=0):
    return 1
  else:
    return 0

# %%
#parâmetros iniciais

point = (1,1)
init_weight1 = 3
init_weight2 = 4
init_bias = -10
learning_rate = 0.1

graph('(-init_weight1*x-init_bias)/init_weight2', range(0, 4),ls='--')

plt.show()

# %%
graph('(-init_weight1*x-init_bias)/init_weight2', range(0, 4),ls='--')
weight1 = init_weight1
weight2 = init_weight2
bias = init_bias

#TODO Código para ajuste de linha e contagem de iterações

count = 0

while check(weight1,weight2,bias) == 0:
  weight1 = weight1+learning_rate*point[0]
  weight2 = weight2+learning_rate*point[1]
  bias = bias + learning_rate*1
  graph('(-weight1*x-bias)/weight2', range(0, 4),ls='-')
  count = count+1


plt.show()
print(count)
# Out:
# 11

# %% [markdown]
# E se passar muitas iterações, o que acontece? Como voltar?
